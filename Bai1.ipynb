# %% [markdown]
# <a href="https://colab.research.google.com/github/HoDinhKhanh/AI/blob/main/Bai1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
value1 = input('Nhập vào số thứ 1: ')
# Out:
# Nhập vào số thứ 1: 7

# %%
value2 = input('nhập vào số thứ 2: ')
# Out:
# nhập vào số thứ 2: 3

# %%
value1 + value2
# Out:
# '73'

# %%
value1 = int(value1)
value2 = int(value2)

# %%
value1 + value2
# Out:
# 10

# %%
# write to file
with open ('text.txt', mode = 'w') as accounts:
  accounts.write('201461 Nguyễn Văn A 10\n')
  accounts.write('201462 Lê Văn B 6\n')
  accounts.write('201463 Trần Văn C 8\n')

# %%
# write to file
with open ('text1.txt', mode = 'w') as accounts:
  print('201461 Nguyễn Văn A', file = accounts)
  print('201462 Lê Văn B ', file = accounts)
  print('201463 Trần Văn C', file = accounts)

# %%
with open ('text2.txt', mode = 'w') as accounts:
  print(f"{'MSSV': <10}{'Name': <20}{'Score': >2}")
  for record in accounts:
    mssv, name, score = record.split()
    print(f"{mssv: <10}{name: <20}{score: >2}")

# %%
import pandas as pd
url = 'california_cities.csv'
dataframe = pd.read_csv(url)
dataframe.head(21)
# Out:
#     Unnamed: 0            city       latd       longd  elevation_m  \
# 0            0        Adelanto  34.576111 -117.432778        875.0
# 1            1     AgouraHills  34.153333 -118.761667        281.0
# 2            2         Alameda  37.756111 -122.274444          NaN
# 3            3          Albany  37.886944 -122.297778          NaN
# 4            4        Alhambra  34.081944 -118.135000        150.0
# 5            5      AlisoViejo  33.575000 -117.725556        127.0
# 6            6         Alturas  41.487222 -120.542500       1332.0
# 7            7      AmadorCity  38.419444 -120.824167        280.0
# 8            8  AmericanCanyon  38.168056 -122.252500         14.0
# 9            9         Anaheim  33.836111 -117.889722         48.0
# 10          10        Anderson  40.452222 -122.296667        132.0
# 11          11      AngelsCamp  38.068333 -120.539722        420.0
# 12          12         Antioch  38.005000 -121.805833         13.0
# ...

# %%
dataframe.iloc[:10]
# Out:
#    Unnamed: 0            city       latd       longd  elevation_m  \
# 0           0        Adelanto  34.576111 -117.432778        875.0
# 1           1     AgouraHills  34.153333 -118.761667        281.0
# 2           2         Alameda  37.756111 -122.274444          NaN
# 3           3          Albany  37.886944 -122.297778          NaN
# 4           4        Alhambra  34.081944 -118.135000        150.0
# 5           5      AlisoViejo  33.575000 -117.725556        127.0
# 6           6         Alturas  41.487222 -120.542500       1332.0
# 7           7      AmadorCity  38.419444 -120.824167        280.0
# 8           8  AmericanCanyon  38.168056 -122.252500         14.0
# 9           9         Anaheim  33.836111 -117.889722         48.0
#
#    elevation_ft  population_total  area_total_sq_mi  area_land_sq_mi  \
# 0        2871.0             31765            56.027           56.009
# 1         922.0             20330             7.822            7.793
# ...

# %%
dataframe = dataframe.set_index(dataframe['city'])
dataframe.loc['Alturas']
# Out:
# Unnamed: 0                    6
# city                    Alturas
# latd                  41.487222
# longd                 -120.5425
# elevation_m              1332.0
# elevation_ft             4370.0
# population_total           2827
# area_total_sq_mi          2.449
# area_land_sq_mi           2.435
# area_water_sq_mi          0.014
# area_total_km2            6.342
# area_land_km2             6.306
# area_water_km2            0.036
# area_water_percent         0.57
# Name: Alturas, dtype: object

# %%
dataframe[dataframe['city'] == 'Arcadia'].head(10)
# Out:
#          Unnamed: 0     city       latd       longd  elevation_m  \
# city
# Arcadia          14  Arcadia  34.132778 -118.036389        147.0
#
#          elevation_ft  population_total  area_total_sq_mi  area_land_sq_mi  \
# city
# Arcadia         482.0             56364            11.133           10.925
#
#          area_water_sq_mi  area_total_km2  area_land_km2  area_water_km2  \
# city
# Arcadia             0.208          28.836         28.296            0.54
#
#          area_water_percent
# city
# Arcadia                1.87

# %%
dataframe[(dataframe['area_total_km2'] == 145.107) & (dataframe['city'] == 'Adelanto')]
# Out:
#           Unnamed: 0      city       latd       longd  elevation_m  \
# city
# Adelanto           0  Adelanto  34.576111 -117.432778        875.0
#
#           elevation_ft  population_total  area_total_sq_mi  area_land_sq_mi  \
# city
# Adelanto        2871.0             31765            56.027           56.009
#
#           area_water_sq_mi  area_total_km2  area_land_km2  area_water_km2  \
# city
# Adelanto             0.018         145.107        145.062           0.046
#
#           area_water_percent
# city
# Adelanto                0.03

# %%
dataframe['city'].replace('Adelanto', 'Ho Dinh Khanh').head(10)
# Out:
# city
# Adelanto           Ho Dinh Khanh
# AgouraHills          AgouraHills
# Alameda                  Alameda
# Albany                    Albany
# Alhambra                Alhambra
# AlisoViejo            AlisoViejo
# Alturas                  Alturas
# AmadorCity            AmadorCity
# AmericanCanyon    AmericanCanyon
# Anaheim                  Anaheim
# Name: city, dtype: object

# %%
dataframe.replace('Adelanto', 'Ho Dinh Khanh').head(10)
# Out:
#                 Unnamed: 0            city       latd       longd  \
# city
# Adelanto                 0   Ho Dinh Khanh  34.576111 -117.432778
# AgouraHills              1     AgouraHills  34.153333 -118.761667
# Alameda                  2         Alameda  37.756111 -122.274444
# Albany                   3          Albany  37.886944 -122.297778
# Alhambra                 4        Alhambra  34.081944 -118.135000
# AlisoViejo               5      AlisoViejo  33.575000 -117.725556
# Alturas                  6         Alturas  41.487222 -120.542500
# AmadorCity               7      AmadorCity  38.419444 -120.824167
# AmericanCanyon           8  AmericanCanyon  38.168056 -122.252500
# Anaheim                  9         Anaheim  33.836111 -117.889722
#
#                 elevation_m  elevation_ft  population_total  area_total_sq_mi  \
# city
# Adelanto              875.0        2871.0             31765            56.027
# ...

# %%
print('Diện tích lớn nhất: ', dataframe['area_total_km2'].max())
print('Diện tích nhỏ nhất: ', dataframe['area_total_km2'].min())
print('Diện tích trung bình: ', dataframe['area_total_km2'].mean())
print('Tổng diện tích: ', dataframe['area_total_km2'].sum())
print('Tổng: ', dataframe['area_total_km2'].count())
# Out:
# Diện tích lớn nhất:  1302.0
# Diện tích nhỏ nhất:  0.813
# Diện tích trung bình:  46.753283018867926
# Tổng diện tích:  22301.316
# Tổng:  477

# %%
dataframe['city'].unique()
# Out:
# array(['Adelanto', 'AgouraHills', 'Alameda', 'Albany', 'Alhambra',
#        'AlisoViejo', 'Alturas', 'AmadorCity', 'AmericanCanyon', 'Anaheim',
#        'Anderson', 'AngelsCamp', 'Antioch', 'AppleValley', 'Arcadia',
#        'Arcata', 'ArroyoGrande', 'Artesia', 'Arvin', 'Atascadero',
#        'Atherton', 'Atwater', 'Auburn', 'Avalon', 'Avenal', 'Azusa',
#        'Bakersfield', 'BaldwinPark', 'Banning', 'Barstow', 'Beaumont',
#        'Bell', 'Bellflower', 'BellGardens', 'Belmont', 'Belvedere',
#        'Benicia', 'Berkeley', 'BeverlyHills', 'BigBearLake', 'Biggs',
#        'Bishop', 'BlueLake', 'Blythe', 'Bradbury', 'Brawley', 'Brea',
#        'Brentwood', 'Brisbane', 'Buellton', 'BuenaPark', 'Burbank',
#        'Burlingame', 'Calabasas', 'Calexico', 'CaliforniaCity',
#        'Calimesa', 'Calipatria', 'Calistoga', 'Camarillo', 'Campbell',
#        'CanyonLake', 'Capitola', 'Carlsbad', 'CarmelbytheSea',
#        'Carpinteria', 'Carson', 'CathedralCity', 'Ceres', 'Cerritos',
# ...

# %%
dataframe['area_total_km2'].value_counts()
# Out:
# 12.536     2
# 3.496      2
# 7.607      2
# 4.949      2
# 6.379      2
#           ..
# 79.212     1
# 41.845     1
# 46.513     1
# 15.191     1
# 103.639    1
# Name: area_total_km2, Length: 472, dtype: int64

# %%
dataframe.drop('area_total_sq_mi', axis = 1)
# Out:
#              Unnamed: 0         city       latd       longd  elevation_m  \
# city
# Adelanto              0     Adelanto  34.576111 -117.432778        875.0
# AgouraHills           1  AgouraHills  34.153333 -118.761667        281.0
# Alameda               2      Alameda  37.756111 -122.274444          NaN
# Albany                3       Albany  37.886944 -122.297778          NaN
# Alhambra              4     Alhambra  34.081944 -118.135000        150.0
# ...                 ...          ...        ...         ...          ...
# Yountville          477   Yountville  38.403056 -122.362222         30.0
# Yreka               478        Yreka  41.726667 -122.637500        787.0
# YubaCity            479     YubaCity  39.134722 -121.626111         18.0
# Yucaipa             480      Yucaipa  34.030278 -117.048611        798.0
# YuccaValley         481  YuccaValley  34.133333 -116.416667       1027.0
#
#              elevation_ft  population_total  area_land_sq_mi  \
# city
# ...

# %%
dataframe.drop(['area_land_sq_mi', 'area_water_sq_mi'], axis=1).head(10)
# Out:
#                 Unnamed: 0            city       latd       longd  \
# city
# Adelanto                 0        Adelanto  34.576111 -117.432778
# AgouraHills              1     AgouraHills  34.153333 -118.761667
# Alameda                  2         Alameda  37.756111 -122.274444
# Albany                   3          Albany  37.886944 -122.297778
# Alhambra                 4        Alhambra  34.081944 -118.135000
# AlisoViejo               5      AlisoViejo  33.575000 -117.725556
# Alturas                  6         Alturas  41.487222 -120.542500
# AmadorCity               7      AmadorCity  38.419444 -120.824167
# AmericanCanyon           8  AmericanCanyon  38.168056 -122.252500
# Anaheim                  9         Anaheim  33.836111 -117.889722
#
#                 elevation_m  elevation_ft  population_total  area_total_sq_mi  \
# city
# Adelanto              875.0        2871.0             31765            56.027
# ...

# %%
dataframe.drop(dataframe.columns[2:4], axis=1).head(10)
# Out:
#                 Unnamed: 0            city  elevation_m  elevation_ft  \
# city
# Adelanto                 0        Adelanto        875.0        2871.0
# AgouraHills              1     AgouraHills        281.0         922.0
# Alameda                  2         Alameda          NaN          33.0
# Albany                   3          Albany          NaN          43.0
# Alhambra                 4        Alhambra        150.0         492.0
# AlisoViejo               5      AlisoViejo        127.0         417.0
# Alturas                  6         Alturas       1332.0        4370.0
# AmadorCity               7      AmadorCity        280.0         919.0
# AmericanCanyon           8  AmericanCanyon         14.0          46.0
# Anaheim                  9         Anaheim         48.0         157.0
#
#                 population_total  area_total_sq_mi  area_land_sq_mi  \
# city
# Adelanto                   31765            56.027           56.009
# ...

# %%
dataframe[dataframe['city'] != 'Adelanto'].head(10)
# Out:
#                 Unnamed: 0            city       latd       longd  \
# city
# AgouraHills              1     AgouraHills  34.153333 -118.761667
# Alameda                  2         Alameda  37.756111 -122.274444
# Albany                   3          Albany  37.886944 -122.297778
# Alhambra                 4        Alhambra  34.081944 -118.135000
# AlisoViejo               5      AlisoViejo  33.575000 -117.725556
# Alturas                  6         Alturas  41.487222 -120.542500
# AmadorCity               7      AmadorCity  38.419444 -120.824167
# AmericanCanyon           8  AmericanCanyon  38.168056 -122.252500
# Anaheim                  9         Anaheim  33.836111 -117.889722
# Anderson                10        Anderson  40.452222 -122.296667
#
#                 elevation_m  elevation_ft  population_total  area_total_sq_mi  \
# city
# AgouraHills           281.0         922.0             20330             7.822
# ...

# %%
dataframe[dataframe['population_total'] != 185].head(10)
# Out:
#                 Unnamed: 0            city       latd       longd  \
# city
# Adelanto                 0        Adelanto  34.576111 -117.432778
# AgouraHills              1     AgouraHills  34.153333 -118.761667
# Alameda                  2         Alameda  37.756111 -122.274444
# Albany                   3          Albany  37.886944 -122.297778
# Alhambra                 4        Alhambra  34.081944 -118.135000
# AlisoViejo               5      AlisoViejo  33.575000 -117.725556
# Alturas                  6         Alturas  41.487222 -120.542500
# AmericanCanyon           8  AmericanCanyon  38.168056 -122.252500
# Anaheim                  9         Anaheim  33.836111 -117.889722
# Anderson                10        Anderson  40.452222 -122.296667
#
#                 elevation_m  elevation_ft  population_total  area_total_sq_mi  \
# city
# Adelanto              875.0        2871.0             31765            56.027
# ...

# %%
dataframe.drop_duplicates().head(10)
# Out:
#                 Unnamed: 0            city       latd       longd  \
# city
# Adelanto                 0        Adelanto  34.576111 -117.432778
# AgouraHills              1     AgouraHills  34.153333 -118.761667
# Alameda                  2         Alameda  37.756111 -122.274444
# Albany                   3          Albany  37.886944 -122.297778
# Alhambra                 4        Alhambra  34.081944 -118.135000
# AlisoViejo               5      AlisoViejo  33.575000 -117.725556
# Alturas                  6         Alturas  41.487222 -120.542500
# AmadorCity               7      AmadorCity  38.419444 -120.824167
# AmericanCanyon           8  AmericanCanyon  38.168056 -122.252500
# Anaheim                  9         Anaheim  33.836111 -117.889722
#
#                 elevation_m  elevation_ft  population_total  area_total_sq_mi  \
# city
# Adelanto              875.0        2871.0             31765            56.027
# ...

# %%
dataframe.groupby('area_total_km2').count()
# Out:
#                 Unnamed: 0  city  latd  longd  elevation_m  elevation_ft  \
# area_total_km2
# 0.813                    1     1     1      1            1             1
# 0.921                    1     1     1      1            1             1
# 1.067                    1     1     1      1            1             1
# 1.251                    1     1     1      1            1             1
# 1.272                    1     1     1      1            1             1
# ...                    ...   ...   ...    ...          ...           ...
# 371.946                  1     1     1      1            0             1
# 466.109                  1     1     1      1            1             0
# 527.401                  1     1     1      1            1             1
# 964.510                  1     1     1      1            1             1
# 1302.000                 1     1     1      1            1             1
#
#                 population_total  area_total_sq_mi  area_land_sq_mi  \
# ...

# %%
dataframe.groupby(['area_total_km2', 'population_total']).count()
# Out:
#                                  Unnamed: 0  city  latd  longd  elevation_m  \
# area_total_km2 population_total
# 0.813          185                        1     1     1      1            1
# 0.921          769                        1     1     1      1            1
# 1.067          1010                       1     1     1      1            1
# 1.251          1624                       1     1     1      1            1
# 1.272          804                        1     1     1      1            1
# ...                                     ...   ...   ...    ...          ...
# 371.946        347483                     1     1     1      1            0
# 466.109        1000536                    1     1     1      1            1
# 527.401        14120                      1     1     1      1            1
# 964.510        1345895                    1     1     1      1            1
# 1302.000       3884307                    1     1     1      1            1
#
# ...

# %%
import numpy as np
import pandas as pd

# %%
time_index = pd.date_range('01/01/2023', periods = 100000, freq = '30s')
dataframe = pd.DataFrame(index = time_index)
dataframe['Acess_Amount'] = np.random.randint(1,10,100000)
dataframe.resample('W').sum()
# Out:
#             Acess_Amount
# 2023-01-01         14538
# 2023-01-08        101197
# 2023-01-15        100775
# 2023-01-22        100820
# 2023-01-29        100876
# 2023-02-05         82588

# %%
dataframe.resample('2W').mean()
# Out:
#             Acess_Amount
# 2023-01-01      5.047917
# 2023-01-15      5.009226
# 2023-01-29      5.002381
# 2023-02-12      5.011408

# %%
dataframe.resample('M').mean()
# Out:
#             Acess_Amount
# 2023-01-31      5.004727
# 2023-02-28      5.034701

# %%
import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)

# %%
# tìm số lượng huy chương của CAN
# tìm số huy chương vàng theo môn thi cá nhân
data1=data[(data['Event'] =='individual') & (data['Medal']=='Gold')] 
print("Số huy chương chương vàng theo môn cá nhân:",data1['Event'].count())
data2 = data[(data['NOC'] == 'CAN')]
print('số lượng huy chương của CAN: ', data2['Medal'].count())
# Out:
# Số huy chương chương vàng theo môn cá nhân: 65
# số lượng huy chương của CAN:  119
